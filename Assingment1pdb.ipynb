# %%
import matplotlib as plt

# %%
import numpy as np

# %%
from matplotlib import pyplot

# %%
import pandas as pd

# %%
path="C:\\Users\\Miste\\Desktop\\jsrt_metadata.csv"
df=pd.read_csv(path)

# %%
missingdata = df.isnull()

miss = df.isnull()

# %%
miss.sum()
A = df["size"].astype("float").mean(axis=0)
df["size"].replace(np.nan,A,inplace = True)

A = df["subtlety"].astype("float").mean(axis=0)
df["subtlety"].replace(np.nan,A,inplace = True)

A = df["y"].astype("float").mean(axis=0)
df["y"].replace(np.nan,A,inplace = True)

A = df["x"].astype("float").mean(axis=0)
df["x"].replace(np.nan,A,inplace = True)

M = df["position"].value_counts().idxmax()
df["position"].replace(np.nan, M, inplace=True)

M = df["diagnosis"].value_counts().idxmax()
df["diagnosis"].replace(np.nan, M, inplace=True)

miss = df.isnull()
miss.sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %% [markdown]
# # 1. Find the total number of patients of each disease (diagnosis) and plot in histogram.

# %%
df["diagnosis"].value_counts()
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# ...

# %%
dat=df["diagnosis"]
pd.Series(data=dat).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.pyplot.hist(df["diagnosis"],edgecolor="black")
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 2. Find the total number of patients of each disease (diagnosis) with respect to the disease state(malignant or benign) and plot in a pie chart.

# %%
df=pd.read_csv(path)
bf=df.dropna()
df["state"].value_counts()
# Out:
# malignant     100
# non-nodule     93
# benign         54
# Name: state, dtype: int64

# %%
plt.pyplot.pie(bf["state"].value_counts(),shadow=True,
               labels=["malignant","benign"],colors=["green","red","blue"],autopct="%1.1f%%",
              startangle=90)

print("Pie chart, patient ratio with respect to two states benign and maliganant")
# Out:
# Pie chart, patient ratio with respect to two states benign and maliganant

# %%
plt.pyplot.pie(bf["diagnosis"].value_counts(),shadow=True,
               labels=["lung cancer",
"lung cancer(adenocarcinoma)",
"tuberculoma",
"granuloma",
"lung cancer(bronchioloalveolar cell carcinoma)",
"metastasis of colon cancer",
"inflammatory mass","unknow",
"pulmonary tuberculosis",
"lung abscess",
"Cryptococcosis",
"lung cancer(squamous cell carcinoma)",
"Inflammatory mass",
"pulmonary hematoma",
"susp. inflammatory mass",
"hamartoma",
"sclerosing hemangioma",
"lung cancer(large cell carcinoma)",
"susp. hamartoma",
"metastasis of uterine cancer",
"organizing pneumonia",
"metastasis of ovarian cancer",
"metastatic lung cancer",
"lung canceror metastasis",
"pneumonia",
"calcified granuloma",
"lung cancer(adenosquamous carcinoma)",
"lung cancer(small cell carcinoma)",
"susp.tuberculoma",
"organiging pneumonia",
"susp. sclerosing hemangioma",
"susp. lung metastasis",],colors=["green","red","blue"],autopct="%1.1f%%",
              startangle=90)

print("Pie chart, desiase ratio with respect to two states benign and maliganant")
# Out:
# Pie chart, desiase ratio with respect to two states benign and maliganant

# %% [markdown]
# # 3 Find and plot via pia chart the total number of patients of each disease (diagnosis) with respect to the gender(Female,Male)

# %%
plt.pyplot.pie(df["gender"].value_counts(),shadow=True,
               labels=["female","male"],colors=["green","red","blue"],autopct="%1.1f%%",
              startangle=90)

print("Pie chart, patient ratio with respect to gender")
df["gender"].value_counts()
# Out:
# Pie chart, patient ratio with respect to gender
# Female    128
# Male      119
# Name: gender, dtype: int64
